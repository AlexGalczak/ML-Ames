# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ### `Load CSV`

# %%
house_price = pd.read_csv('Ames_HousePrice_cleaned.csv')
house_price
# Out:
#             PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotArea LotShape  \
# 0     909176150        856     126000          30       RL     7890      Reg
# 1     905476230       1049     139500         120       RL     4235      Reg
# 2     911128020       1001     124900          30  C (all)     6060      Reg
# 3     535377150       1039     114000          70       RL     8146      Reg
# 4     534177230       1665     227000          60       RL     8400      Reg
# ...         ...        ...        ...         ...      ...      ...      ...
# 2575  903205040        952     121000          30       RL     8854      Reg
# 2576  905402060       1733     139600          20       RL    13680      IR1
# 2577  909275030       2002     145000          90       RH     6270      Reg
# 2578  907192040       1842     217500          60       RL     8826      Reg
# 2579  906223180       1911     215000          60       RL     9554      IR1
#
# ...

# %% [markdown]
# ### `Checking NA Values`

# %%
np.sum(house_price.isnull()).head()

# GarageType       127
# BsmtFinType2      70
# BsmtFinType1      69
# BsmtQual          69
# BsmtCond          69
# BsmtExposure      71
# Out:
# PID           0
# GrLivArea     0
# SalePrice     0
# MSSubClass    0
# MSZoning      0
# dtype: int64

# %% [markdown]
# ### `Removing Outliers`

# %%
# NA values can come in other forms (not just NA) 
# house_price[house_price['LotArea' == max('LotArea')]] 

house_price.LotArea.max()
#215245
house_price.loc[house_price.LotArea == 215245, 'PID']
# returns PID value 916176125
house_price.shape
#(2580, 49)
house_price = house_price[~(house_price.LotArea == 215245)]
house_price.shape
#(2579, 49)
# Out:
# (2579, 49)
